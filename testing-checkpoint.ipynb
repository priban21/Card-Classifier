# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import load_img
import os
import joblib
import numpy as np
from tensorflow.keras.preprocessing import image
from PIL import Image

# %%
dataset_path = "C:/Users/PBanerjee/Desktop/DIGI_PROJ/DATASET"
batch_size = 32
img_size = (255, 255)
epochs = 10

# %%
datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values
    rotation_range=20,  # Rotate images randomly
    zoom_range=0.2,  # Random zoom
    horizontal_flip=True,  # Flip images horizontally
    validation_split=0.2  # 80-20 train-validation split
)

# %%
train_gen = datagen.flow_from_directory(
    dataset_path, target_size=img_size, batch_size=batch_size, class_mode='binary', subset="training"
)
# Out:
# Found 3498 images belonging to 2 classes.

# %%
val_gen = datagen.flow_from_directory(
    dataset_path, target_size=img_size, batch_size=batch_size, class_mode='binary', subset="validation"
)
# Out:
# Found 874 images belonging to 2 classes.

# %%
print(train_gen.class_indices)
# Out:
# {'AADHAAR': 0, 'PAN': 1}

# %%
resnet_model = Sequential()

pretrained_model= ResNet50(include_top=False,
                   input_shape=(255,255,3),
                   pooling='max',classes=2,
                   weights='imagenet')
for layer in pretrained_model.layers:
        layer.trainable=False

resnet_model.add(pretrained_model)
resnet_model.add(Flatten())
resnet_model.add(Dense(512, activation='relu'))
resnet_model.add(Dropout(0.2))
resnet_model.add(Dense(128, activation='relu'))
resnet_model.add(Dense(64, activation='relu'))
resnet_model.add(Dense(1, activation='sigmoid'))

# %%
resnet_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 2048)                │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 512)                 │       1,049,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 512)                 │               0 │
# ...

# %%
resnet_model.compile(optimizer=Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = resnet_model.fit(
  train_gen,
  validation_data=val_gen,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 305s 3s/step - accuracy: 0.5741 - loss: 0.8925 - val_accuracy: 0.6087 - val_loss: 0.6208
# Epoch 2/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 266s 2s/step - accuracy: 0.7735 - loss: 0.4674 - val_accuracy: 0.8822 - val_loss: 0.3024
# Epoch 3/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 286s 3s/step - accuracy: 0.9215 - loss: 0.2220 - val_accuracy: 0.9016 - val_loss: 0.2541
# Epoch 4/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.9249 - loss: 0.1943 - val_accuracy: 0.8924 - val_loss: 0.2705
# Epoch 5/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 252s 2s/step - accuracy: 0.9221 - loss: 0.1915 - val_accuracy: 0.9016 - val_loss: 0.2802
# Epoch 6/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.9367 - loss: 0.1791 - val_accuracy: 0.8833 - val_loss: 0.3545
# Epoch 7/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 252s 2s/step - accuracy: 0.9231 - loss: 0.1834 - val_accuracy: 0.9039 - val_loss: 0.2490
# Epoch 8/10
# ...

# %%
filename = 'resnet50.joblib'
joblib.dump(resnet_model,filename)
# Out:
# ['resnet50.joblib']

# %%
loss,acc = resnet_model.evaluate(val_gen)
print("Validation Accuracy is :",acc*100)
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9157 - loss: 0.2357
# Validation Accuracy is : 89.47368264198303

# %%
def prediction(model,img_path):
    img = image.load_img(img_path, target_size=(255,255))
    img_array = image.img_to_array(img) / 255.0  # Normalize
    img_array = np.expand_dims(img_array, axis=0)
    prediction = model.predict(img_array)[0][0]
    if prediction >= 0.5:
        print("Predicted: PAN Card")
    else:
        print("Predicted: Aadhaar Card")

# %%
# Load the trained model
model = joblib.load(filename)

# %%
img = Image.open("C:/Users/PBanerjee/Desktop/aadhaar2.jpg")
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %%
prediction(model,"C:/Users/PBanerjee/Desktop/aadhaar2.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Predicted: Aadhaar Card

# %%
img = Image.open("C:/Users/PBanerjee/Desktop/pan1.jpg")
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=279x180>

# %%
prediction(model,"C:/Users/PBanerjee/Desktop/pan1.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Predicted: PAN Card
